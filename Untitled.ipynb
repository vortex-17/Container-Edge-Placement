# %%
#For graphs

import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
import math

# %%
# total_nodes = np.asarray([30,70,90,150,200,400,600,750,1100,2200,3000])
# bestfit_nodes = np.asarray([27,63,88,140,184,333,542,607,1013,2026,2535])
# custom_nodes = np.asarray([27,62,87,138,182,327,539,599,1002,2001,2507])

# total_nodes = np.asarray([400,600,750,1100,2200,3000,3500])
total_nodes = np.asarray([450,1000,1200,2000,4000,5000,6000])
bestfit_nodes = np.asarray([333,542,607,1013,2026,2535,2983])
custom_nodes = np.asarray([327,539,599,1002,2001,2507,2900])

# normalised_bestfit = preprocessing.normalize(bestfit_nodes, axis = 0)

# norm1 = total_nodes / np.linalg.norm(total_nodes)
# norm2 = (bestfit_nodes / np.linalg.norm(bestfit_nodes))
# norm3 = (custom_nodes / np.linalg.norm(custom_nodes)) 
# print(norm2)

plt.figure(figsize=(10,10)) 
plt.plot(total_nodes, bestfit_nodes, color='green', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='black', markersize=3, label = "BestFit")
plt.plot(total_nodes, custom_nodes, color='orange', linewidth = 2,
         marker='o', markerfacecolor='black', markersize=3, label = "C-Scale")
plt.ylabel('Edge nodes used for placing containers', fontsize = 18)
# naming the y axis
plt.xlabel('Containers', fontsize=18)
plt.legend(loc=2, prop={'size': 25})
plt.show()

# %%
x = np.arange(5)
plt.bar(x, norm2, color = "black")
plt.bar(x + 0.1 , norm3, color = "red")
plt.xticks(x, ['Team A', 'Team B', 'Team C', 'Team D', 'Team E'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-db9492ae269a> in <module>
#       1 x = np.arange(5)
# ----> 2 plt.bar(x, norm2, color = "black")
#       3 plt.bar(x + 0.1 , norm3, color = "red")
#       4 plt.xticks(x, ['Team A', 'Team B', 'Team C', 'Team D', 'Team E'])
#       5 plt.show()
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
# total_nodes = np.asarray([30,70,90,150,200,400,600,750,1100,2200,3000])
# bestfit_nodes = np.asarray([27,63,88,140,184,333,542,607,1013,2026,2535])
# custom_nodes = np.asarray([27,62,87,138,182,327,539,599,1002,2001,2507])

total_nodes = np.asarray([400,600,750,1100,2200,3000,3500])
bestfit_nodes = np.asarray([5400,8200,9760,16110,32820,40920,42983])
custom_nodes = np.asarray([4500,7400,8400,14310,29170,36720,37900])

# normalised_bestfit = preprocessing.normalize(bestfit_nodes, axis = 0)

# norm1 = total_nodes / np.linalg.norm(total_nodes)
# norm2 = (bestfit_nodes / np.linalg.norm(bestfit_nodes))
# norm3 = (custom_nodes / np.linalg.norm(custom_nodes)) 
# print(norm2)

plt.figure(figsize=(10,10)) 
plt.plot(total_nodes, bestfit_nodes, color='green', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='black', markersize=3, label = "BestFit")
plt.plot(total_nodes, custom_nodes, color='orange', linewidth = 2,
         marker='o', markerfacecolor='black', markersize=3, label = "C-Scale")
plt.ylabel('Total Resource Loss',fontsize = 18)
# naming the y axis
plt.xlabel('Total number of edge nodes',fontsize = 18)
plt.legend(loc=2, prop={'size': 25})
plt.show()

# %%
# total_nodes = np.asarray([30,70,90,150,200,400,600,750,1100,2200,3000])
# bestfit_nodes = np.asarray([27,63,88,140,184,333,542,607,1013,2026,2535])
# custom_nodes = np.asarray([27,62,87,138,182,327,539,599,1002,2001,2507])

total_nodes = np.asarray([1000,1200,2000,4000,5000,6000])
# total_nodes = np.asarray([400,600,750,1100,2200,3000,3500])
bestfit_nodes = np.asarray([313,438,717,1447,1778,1840])
custom_nodes = np.asarray([291,428,700,1405,1719,1779])

# normalised_bestfit = preprocessing.normalize(bestfit_nodes, axis = 0)

# norm1 = total_nodes / np.linalg.norm(total_nodes)
# norm2 = (bestfit_nodes / np.linalg.norm(bestfit_nodes))
# norm3 = (custom_nodes / np.linalg.norm(custom_nodes)) 
# print(norm2)

plt.figure(figsize=(10,10)) 
plt.plot(total_nodes, bestfit_nodes, color='green', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='black', markersize=3, label = "BestFit")
plt.plot(total_nodes, custom_nodes, color='orange', linewidth = 2,
         marker='o', markerfacecolor='black', markersize=3, label = "C-Scale")
plt.ylabel('Number of migrations',fontsize = 18)
# naming the y axis
plt.xlabel('Total number of containers',fontsize = 18)
plt.legend(loc=2, prop={'size': 25})
plt.show()
